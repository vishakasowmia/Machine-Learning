# %% [markdown]
# Exploratory Analysis for accident dataset for according to the type of weather condition in India.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("/content/Acc_Classified_according_to_Type_of_Weather_Condition_2014_and_2016 (2).csv")

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36 entries, 0 to 35
# Data columns (total 65 columns):
#  #   Column                                                          Non-Null Count  Dtype
# ---  ------                                                          --------------  -----
#  0   S. No.                                                          36 non-null     object
#  1   State                                                           36 non-null     object
#  2   FineTotalAcc2014                                                35 non-null     float64
#  3   FinePersonsKilled2014                                           36 non-null     int64
#  4   FinePersonsInjured2014                                          35 non-null     float64
#  5   Mist/fogTotalAcc2014                                            30 non-null     float64
#  6   Mist/fogPersonsKilled2014                                       30 non-null     float64
# ...

# %%
df = data.drop(columns =['Fine/ClearTotalAccidents2016','Fine/ClearPersonsKilled2016','Fine/Clear - Persons Injured - 2016',"Mist/ FoggyTotalAccidents2016","Mist/ Foggy - Persons Killed - 2016","Mist/ FoggyPersonsInjured2016","CloudyTotalAccidents2016","CloudyPersonsKilled2016","CloudyPersonsInjured2016","RainyTotalAccidents2016","RainyPersonsKilled2016","RainyPersonsInjured2016","SnowfallTotalAccidents2016","SnowfallPersonsKilled2016","SnowfallPersonsInjured2016","Hail/SleetTotal Accidents2016","Hail/SleetPersonsKilled2016","Hail/SleetPersonsInjured2016","Dust StormTotalAccidents2016","Dust StormPersonsKilled2016","Dust StormPersonsInjured2016","OthersTotalAccidents2016","OthersPersonsKilled2016","OthersPersonsInjured2016"])
df
# Out:
#    S. No.              State  FineTotalAcc2014  FinePersonsKilled2014  \
# 0       1     Andhra Pradesh           14591.0                   4586
# 1       2  Arunachal Pradesh              71.0                     30
# 2       3              Assam            3575.0                   1318
# 3       4              Bihar            2343.0                   1218
# 4       5       Chhattisgarh            5000.0                   1354
# 5       6                Goa            3556.0                    257
# 6       7            Gujarat           15008.0                   4876
# 7       8            Haryana            5519.0                   2043
# 8       9   Himachal Pradesh            2070.0                    736
# 9      10    Jammu & Kashmir            5290.0                    816
# 10     11          Jharkhand            1249.0                    751
# 11     12          Karnataka           27346.0                   6533
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36 entries, 0 to 35
# Data columns (total 41 columns):
#  #   Column                                                          Non-Null Count  Dtype
# ---  ------                                                          --------------  -----
#  0   S. No.                                                          36 non-null     object
#  1   State                                                           36 non-null     object
#  2   FineTotalAcc2014                                                35 non-null     float64
#  3   FinePersonsKilled2014                                           36 non-null     int64
#  4   FinePersonsInjured2014                                          35 non-null     float64
#  5   Mist/fogTotalAcc2014                                            30 non-null     float64
#  6   Mist/fogPersonsKilled2014                                       30 non-null     float64
# ...

# %%
df.fillna(method ='ffill',inplace = True)

# %%
df.isnull().sum()
# Out:
# S. No.                                                            0
# State                                                             0
# FineTotalAcc2014                                                  0
# FinePersonsKilled2014                                             0
# FinePersonsInjured2014                                            0
# Mist/fogTotalAcc2014                                              0
# Mist/fogPersonsKilled2014                                         0
# Mist/fogPersonInjured2014                                         0
# CloudyTotalAcc2014                                                0
# CloudyPersonsKilled2014                                           0
# CloudyPersonsInjured2014                                          0
# LightrainTotalAcc2014                                             0
# LightrainPersonsKilled2014                                        0
# LightrainPersonsInjured2014                                       0
# ...

# %%
df.drop([35], axis=0, inplace=True)

# %%
State_col= df.filter(['State'], axis=1)

# %%
Total_Acc_col= df.filter(['FineTotalAcc2014'], axis=1)

# %%
summer_season  = df.filter(['VeryhotTotalAcc2014'], axis=1)

# %%
Winter_Season = df.filter(['snowTotalAcc2014','Hail/sleetTotalAcc2014','Mist/fogTotalAcc2014'], axis=1)

# %%
Winter_Season_1= Winter_Season.sum(axis=1)

# %%
winter = Winter_Season_1.to_numpy()
df1 = pd.DataFrame(winter, columns = ["winter"])

# %%
Monsoon_Season = df.filter(["StrongwindTotalAcc2014","DuststormTotalAcc2014","HeavyrainTotalAcc2014","LightrainTotalAcc2014","CloudyTotalAcc2014"])

# %%
Monsoon_Season_1= Monsoon_Season.sum(axis=1)

# %%
monsoon = Monsoon_Season_1.to_numpy()
df2 = pd.DataFrame(monsoon, columns = ["monsoon"])

# %%
df2.isna().sum()
# Out:
# monsoon    0
# dtype: int64

# %%
Post_monsoon_Season =  data.filter(["VerycoldTotalAcc2014"])

# %%
Post_monsoon_Season.fillna(method = "backfill", inplace =True)

# %%
Post_monsoon_Season.isna().sum()
# Out:
# VerycoldTotalAcc2014    0
# dtype: int64

# %%
Other_extreme_cliamte = data.filter(["OtherextraordinaryweatherconditionTotalAcc2014","Floodingofslipways/rivulersTotal Acc2014"])

# %%
Other_extreme_cliamte = Other_extreme_cliamte.sum(axis=1)

# %%
Other_extreme_cliamte = Other_extreme_cliamte.to_numpy()
df3 = pd.DataFrame(Other_extreme_cliamte, columns = ["Other extreme cliamte"])

# %%
y1 = Total_Acc_col["FineTotalAcc2014"].astype(int)
y4 = df1["winter"].astype(int)
y3 = df2["monsoon"].astype(int)
y2 = summer_season["VeryhotTotalAcc2014"].astype(int)
y5 = Post_monsoon_Season["VerycoldTotalAcc2014"].astype(int)
y6 = df3["Other extreme cliamte"].astype(int)

# %%
y5.drop([35], axis=0, inplace=True)

# %%
y6.drop([35], axis=0, inplace=True)

# %%
x  = State_col["State"]
X = np.arange(35)
plt.xticks(X,x,rotation="vertical")
plt.bar(X, y2, color='b')
plt.bar(X, y3, color='y')
plt.bar(X, y4, color='g')
plt.bar(X, y5, color='c')
plt.bar(X, y6,color="m")
plt.xlabel("States")
plt.ylabel("Seasons")
plt.title("Fig(3).State-wise acciddent based on Seasons")
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 35 entries, 0 to 34
# Data columns (total 41 columns):
#  #   Column                                                          Non-Null Count  Dtype
# ---  ------                                                          --------------  -----
#  0   S. No.                                                          35 non-null     object
#  1   State                                                           35 non-null     object
#  2   FineTotalAcc2014                                                35 non-null     float64
#  3   FinePersonsKilled2014                                           35 non-null     int64
#  4   FinePersonsInjured2014                                          35 non-null     float64
#  5   Mist/fogTotalAcc2014                                            35 non-null     float64
#  6   Mist/fogPersonsKilled2014                                       35 non-null     float64
# ...

# %%
dataframe= df.drop(columns =["FinePersonsKilled2014","FinePersonsInjured2014","Mist/fogPersonsKilled2014","Mist/fogPersonInjured2014","CloudyPersonsKilled2014","CloudyPersonsInjured2014","LightrainPersonsKilled2014","LightrainPersonsInjured2014","HeavyrainPersonsKilled2014","HeavyrainPersonsInjured2014","Floodingofslipways/rivulersPersonsKilled2014","Floodingofslipways/rivulersPersonsInjured2014","Hail/sleetPersonsKilled2014","Hail/sleetPersonsInjured2014","snowPersonsKilled2014","snowPersonsInjured2014","StrongwindPersonsKilled2014","StrongwindPersonsInjured2014","DuststormPersonsKilled2014","DuststormPersonsInjured2014","VeryhotPersonsKilled2014","VeryhotPersonsInjured2014","VerycoldPersonsKilled2014","VerycoldPersonsInjured2014","Other extraordinary weather condition - Persons Killed - 2014","Other extraordinary weather condition - Persons Injured - 2014"])

# %%
result = pd.concat([x,y2,y3,y4,y5,y6], axis=1, join='inner')
display(result)
# Out:
#                 State  VeryhotTotalAcc2014  monsoon  winter  \
# 0      Andhra Pradesh                 1264     2966    1313
# 1   Arunachal Pradesh                   23       65      17
# 2               Assam                  170      918     503
# 3               Bihar                  959     2502    1829
# 4        Chhattisgarh                 1186     3766     551
# 5                 Goa                    0      666       0
# 6             Gujarat                 1255     4119     758
# 7             Haryana                  393     1631     964
# 8    Himachal Pradesh                  126      415     121
# 9     Jammu & Kashmir                    0      235     116
# 10          Jharkhand                  392     1822     528
# 11          Karnataka                 1521     6655    1418
# 12             Kerala                    0     7631     477
# 13     Madhya Pradesh                  912     5456    2463
# 14        Maharashtra                  434     2915     290
# ...

# %%
result_sum= result.sum(axis=1)
# Out:
# <ipython-input-36-be4d6cf0e78c>:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   result_sum= result.sum(axis=1)

# %%
result_agg = pd.DataFrame(result_sum, columns = ["Total Accident in  all Season"])

# %%
sum =result_agg.sum(axis=0)
sum
# Out:
# Total Accident in  all Season    182520
# dtype: int64

# %%
result_1 = pd.concat([x,y1], axis=1, join='inner')

# %%
sum_acc = result_1["FineTotalAcc2014"].sum(axis=0)

# %%
fig = plt.figure(figsize=(10,5))
x  = State_col["State"]
X = np.arange(35)
plt.xticks(X,x,rotation="vertical")
plt.title("Fig(4).Summer vs monsoon")
plt.bar(X-0.2, y2, 0.4, label = 'total accident in summer season')
plt.bar(X+0.2, y3, 0.4, label = 'total accident in monsoon season')
plt.legend()
plt.show()

# %%
fig = plt.figure(figsize=(10,5))
x  = State_col["State"]
X = np.arange(35)
plt.xticks(X,x,rotation="vertical")
plt.title("Fig(4).winter vs monsoon")
plt.bar(X-0.2, y4, 0.4, label = 'total accident in winter season')
plt.bar(X+0.2, y3, 0.4, label = 'total accident in monsoon season')
plt.legend()
plt.show()

# %%
fig = plt.figure(figsize=(10,5))
x  = State_col["State"]
X = np.arange(35)
plt.xticks(X,x,rotation="vertical")
plt.title("Fig(4).Post_monsoon vs monsoon")
plt.bar(X-0.2, y5, 0.4, label = 'total accident in post_monsoon season')
plt.bar(X+0.2, y3, 0.4, label = 'total accident in monsoon season')
plt.legend()
plt.show()

# %%
fig = plt.figure(figsize=(10,8))
x  = State_col["State"]
X = np.arange(35)
plt.xticks(X,x,rotation="vertical")
plt.title("Fig(4).other extreme climatic factors vs monsoon")
plt.bar(X-0.2, y6, 0.4, label = 'total accident in other extreme climatic factors')
plt.bar(X+0.2, y3, 0.4, label = 'total accident in monsoon season')
plt.legend()
plt.show()

# %%
fig = plt.figure(figsize=(10,5))
x  = State_col["State"]
X = np.arange(35)
plt.xticks(X,x,rotation="vertical")
plt.title("Fig(5).Winter s vs Summer")
plt.bar(X-0.2, y4, 0.4, label = 'total accident in winter season')
plt.bar(X+0.2, y2, 0.4, label = 'total accident in summer season')
plt.legend()
plt.show()

# %%
fig = plt.figure(figsize=(10,5))
x  = State_col["State"]
X = np.arange(35)
plt.xticks(X,x,rotation="vertical")
plt.title("Fig(5).post_monsoon s vs Summer")
plt.bar(X-0.2, y5, 0.4, label = 'total accident in post_monsoon')
plt.bar(X+0.2, y2, 0.4, label = 'total accident in summer season')
plt.legend()
plt.show()

# %%
fig = plt.figure(figsize=(10,5))
x  = State_col["State"]
X = np.arange(35)
plt.xticks(X,x,rotation="vertical")
plt.title("Fig(5).other extreme climatic factors s vs Summer")
plt.bar(X-0.2, y6, 0.4, label = 'total accident in other climatic factors')
plt.bar(X+0.2, y2, 0.4, label = 'total accident in summer season')
plt.legend()
plt.show()

# %%
fig = plt.figure(figsize=(10,5))
x  = State_col["State"]
X = np.arange(35)
plt.xticks(X,x,rotation="vertical")
plt.title("Fig(6).post_monsoon vs winter")
plt.bar(X-0.2, y5, 0.4, label = 'total accident in post_monsoon')
plt.bar(X+0.2, y4, 0.4, label = 'total accident in winter season')
plt.legend()
plt.show()

# %%
fig = plt.figure(figsize=(10,5))
x  = State_col["State"]
X = np.arange(35)
plt.xticks(X,x,rotation="vertical")
plt.title("Fig(6).Other extreme climatic factors vs winter")
plt.bar(X-0.2, y6, 0.4, label = 'total accident in other climatic factors')
plt.bar(X+0.2, y4, 0.4, label = 'total accident in winter season')
plt.legend()
plt.show()

# %%
fig = plt.figure(figsize=(10,5))
x  = State_col["State"]
X = np.arange(35)
plt.xticks(X,x,rotation="vertical")
plt.title("Fig(7).Other extreme climatic factors vs post-monsoon")
plt.bar(X-0.2, y6, 0.4, label = 'total accident in other climatic factors')
plt.bar(X+0.2, y5, 0.4, label = 'total accident in total accident in post_monsoon')
plt.legend()
plt.show()

# %%
Percentage_of_totalacc_season = sum/sum_acc*100
Percentage_of_totalacc_season
# Out:
# Total Accident in  all Season    58.847236
# dtype: float64

# %%
fig = plt.figure(figsize=(10,5))
x  = State_col["State"]
X = np.arange(35)
plt.xticks(X,x,rotation="vertical")


x2 =result_agg["Total Accident in  all Season"]
x3 =result_1["FineTotalAcc2014"]

plt.plot(x, x2, label = 'Total Accident in all Season',linewidth=2)
plt.plot(x, x3, label = 'Total accident', linewidth=2)
plt.xlabel("State")
plt.ylabel("Seasons")
plt.title("Fig(1).Total accident vs Total Accident in all Season")
plt.legend()
plt.show()

# %%
fig = plt.figure(figsize=(10,5))
x  = State_col["State"]
X = np.arange(35)
plt.xticks(X,x,rotation="vertical")
plt.bar(X-0.2, x2, 0.4, label = 'Total Accident in all Season')
plt.bar(X+0.2, x3, 0.4, label = 'Total accident')
plt.xlabel("State")
plt.ylabel("Seasons")
plt.title("Fig(2).Total accident vs Total Accident in all Season")
plt.legend()
plt.show()
